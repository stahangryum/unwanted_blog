# %%
Hello <- 'Hello World'
Hello
# Out:
# [1] "Hello World"

# %% [markdown]
# # Hello World

# %% [markdown]
# linear

# %% [markdown]
# ![image.png](attachment:bf6223eb-84fe-4754-9739-55bfdc787d51.png)
